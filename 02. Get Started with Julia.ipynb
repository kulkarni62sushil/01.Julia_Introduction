# %% [markdown]
# <h1 align='center' style='color:blue'> 02. Get Started with Julia </h1>

# %% [markdown]
# ![Julia-colorful_800x.jpeg](attachment:Julia-colorful_800x.jpeg)

# %% [markdown]
# #### In this notebook, we will discuss how to
#
# ####  * Install Julia
# #### * Install Jupyter notebook
# #### * Allow Jupyter notebook to run Julia

# %% [markdown]
# ## 1. Install Julia

# %% [markdown]
# Julia Codes can be written, compiled, and Run on multiple platforms like BBEdit on MacOS, Jupyter, etc. Many online IDE’s are also available for Julia. For using it on your own system one can install it in the following ways:

# %% [markdown]
# Go to [Julia Language](https://julialang.org/https://julialang.org/). You will get following screen:

# %% [markdown]
# ![I1.png](attachment:I1.png)

# %% [markdown]
# There is download option. Click [Download](https://julialang.org/downloads/). You will get the following screen after scrolling down.

# %% [markdown]
# ![I2.png](attachment:I2.png)

# %% [markdown]
# Now start downloading `.dmg`file according to you operating System. I am doing it for mac

# %% [markdown]
# Start the installation from the `dmg` file and move the Julia file in the application folder.

# %% [markdown]
# ![I3.png](attachment:I3.png)

# %% [markdown]
# Now click on Julia icon in applications, it will open terminal as follows :

# %% [markdown]
# ![I4.png](attachment:I4.png)

# %% [markdown]
# Julia is installed in your system now you can run a file with the next step.

# %% [markdown]
# Now we can run a simple program like printing " Hello World " and is shown below:

# %% [markdown]
# ![I5.png](attachment:I5.png)

# %% [markdown]
# ##  2.  Install Jupyter notebook

# %% [markdown]
# To run **Julia** on Jupyter notebook, one has to first download Jupyter notebook.
#
# The **Jupyter Notebook** is an open source web application that you can use to create and share documents that contain live code, equations, visualizations, and text. Jupyter Notebook is maintained by the people at [Project Jupyter](https://jupyter.org/).
#
# While `Jupyter` runs code in many programming languages, `Python` is a requirement (Python 3.3 or greater, or Python 2.7) for installing the Jupyter Notebook.
#
# We recommend using the `Anaconda distribution` to install Python and Jupyter.
#
# Next, we’ll go through its installation.

# %% [markdown]
# #### Following are the steps to download **Jupyter Notebook using `Anaconda`**:

# %% [markdown]
# **1.** Open [Anaconda_Installer](https://www.anaconda.com/products/individual) as shown below:

# %% [markdown]
# ![I6.png](attachment:I6.png)

# %% [markdown]
# 2. Click `Get Additional Installers`. You will get the following:

# %% [markdown]
# ![I7.png](attachment:I7.png)

# %% [markdown]
# 3. Click `Python` according to your Operating system. Please note that you require `Python` to run `Jupyter notebook`. Follow the instructions mentioned to download.
#
#
# 4. Now from your `Applications` you will observe that you have `Anaconda-Navigator`. Click it to get the following:

# %% [markdown]
# ![I9.png](attachment:I9.png)

# %% [markdown]
# Click `Launch` to launch `Juppyter`. Now you will get the following screen. When you click `New`, you will get only `Python`

# %% [markdown]
# ![I8.webp](attachment:I8.webp)

# %% [markdown]
#  Alternatively you can open `Jupyter notebook` from `terminal`.
#
#  Type `Jupyter notebook`

# %% [markdown]
# To get `Julia` to run in `Jupyter notebook` we follow the last step as shown below

# %% [markdown]
# ## 3. Add Julia to Jupyter Notebook

# %% [markdown]
# In order to add Julia to Jupyter Notebook, you’ll need to type the following command and then press ENTER:

# %% [markdown]
# ![I10.png](attachment:I10.png)

# %% [markdown]
# Then, type this command and then press ENTER:

# %% [markdown]
# ![I11.png](attachment:I11.png)

# %% [markdown]
# You’ll have to wait for the installation to complete…

# %% [markdown]
# ![I12.png](attachment:I12.png)

# %% [markdown]
# Now `IJulia` is installed. Again open `Jupyter notebook` and you can see that in `New` we have `Julia`

# %% [markdown]
# Next we are ready to write Julia programs
